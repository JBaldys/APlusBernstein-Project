# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from darts import TimeSeries
from darts.datasets import AirPassengersDataset, MonthlyMilkDataset

# %%
series_air = AirPassengersDataset().load().astype(np.float32)
series_milk = MonthlyMilkDataset().load().astype(np.float32)

# set aside last 36 months of each series as validation set:
train_air, val_air = series_air[:-36], series_air[-36:]
train_milk, val_milk = series_milk[:-36], series_milk[-36:]

train_air.plot()
val_air.plot()
train_milk.plot()
val_milk.plot()

# %%
from darts.dataprocessing.transformers import Scaler

scaler = Scaler()
train_air_scaled, train_milk_scaled = scaler.fit_transform([train_air, train_milk])

train_air_scaled.plot()
train_milk_scaled.plot()

# %%
from darts.models import NBEATSModel

model = NBEATSModel(input_chunk_length=24, output_chunk_length=12, random_state=42)

model.fit([train_air_scaled, train_milk_scaled], epochs=50, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/notebooks/models/transformer.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/notebooks/models/transformer.ipynb#ch0000003?line=0'>1</a> from darts.models import NBEATSModel
#       <a href='vscode-notebook-cell:/Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/notebooks/models/transformer.ipynb#ch0000003?line=2'>3</a> model = NBEATSModel(input_chunk_length=24, output_chunk_length=12, random_state=42)
#       <a href='vscode-notebook-cell:/Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/notebooks/models/transformer.ipynb#ch0000003?line=4'>5</a> model.fit([train_air_scaled, train_milk_scaled], epochs=50, verbose=True)
#
# File ~/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/__init__.py:13, in <module>
#      <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/__init__.py?line=10'>11</a> from darts.models.forecasting.arima import ARIMA
#      <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/__init__.py?line=11'>12</a> from darts.models.forecasting.baselines import NaiveDrift, NaiveMean, NaiveSeasonal
# ---> <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/__init__.py?line=12'>13</a> from darts.models.forecasting.croston import Croston
#      <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/__init__.py?line=13'>14</a> from darts.models.forecasting.exponential_smoothing import ExponentialSmoothing
#      <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/__init__.py?line=14'>15</a> from darts.models.forecasting.fft import FFT
#
# File ~/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/forecasting/croston.py:8, in <module>
#       <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/forecasting/croston.py?line=5'>6</a> import numpy as np
#       <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/forecasting/croston.py?line=6'>7</a> from numba.core import errors
# ----> <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/forecasting/croston.py?line=7'>8</a> from statsforecast.models import croston_classic, croston_optimized, croston_sba
#       <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/forecasting/croston.py?line=8'>9</a> from statsforecast.models import tsb as croston_tsb
#      <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/darts/models/forecasting/croston.py?line=10'>11</a> from darts.logging import raise_if, raise_if_not
#
# File ~/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/statsforecast/models.py:14, in <module>
#      <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/statsforecast/models.py?line=11'>12</a> import numpy as np
#      <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/statsforecast/models.py?line=12'>13</a> import pandas as pd
# ---> <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/statsforecast/models.py?line=13'>14</a> from numba import njit
#      <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/statsforecast/models.py?line=14'>15</a> from scipy.optimize import minimize
#      <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/statsforecast/models.py?line=16'>17</a> from .arima import auto_arima_f, forecast_arima
#
# File ~/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py:200, in <module>
#     <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=196'>197</a>     return False
#     <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=198'>199</a> _ensure_llvm()
# --> <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=199'>200</a> _ensure_critical_deps()
#     <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=201'>202</a> # we know llvmlite is working as the above tests passed, import it now as SVML
#     <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=202'>203</a> # needs to mutate runtime options (sets the `-vector-library`).
#     <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=203'>204</a> import llvmlite
#
# File ~/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py:140, in _ensure_critical_deps()
#     <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=137'>138</a>     raise ImportError("Numba needs NumPy 1.18 or greater")
#     <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=138'>139</a> elif numpy_version > (1, 21):
# --> <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=139'>140</a>     raise ImportError("Numba needs NumPy 1.21 or less")
#     <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=141'>142</a> try:
#     <a href='file:///Users/qiushi/workspace/dsi-courses/APlusBernstein-Project/venv/lib/python3.9/site-packages/numba/__init__.py?line=142'>143</a>     import scipy
#
# ImportError: Numba needs NumPy 1.21 or less
